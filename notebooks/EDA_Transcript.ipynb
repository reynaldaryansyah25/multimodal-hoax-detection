# %%
import pandas as pd
import re, string
from spellchecker import SpellChecker
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_json("../data/transcript/metadata.json")  
df.head()
# Out:
#   sample_id   source                          keyword     video_id  \
# 0  YT_00001  youtube  Prabowo presiden Indonesia 2024  IuE7NGQs_xk
# 1  YT_00002  youtube  Prabowo presiden Indonesia 2024  n7rRd0IF_yc
# 2  YT_00003  youtube  Prabowo presiden Indonesia 2024  6f17uwi2Vtw
# 3  YT_00004  youtube  Prabowo presiden Indonesia 2024  ExCBplKi6kw
# 4  YT_00005  youtube      Kabinet merah putih Prabowo  PqjwO9JEtBM
#
#                                                title               channel  \
# 0  Presiden Prabowo Tiba di Malaysia untuk Hadiri...  Sekretariat Presiden
# 1  [FULL] Wapres Gibran Umumkan Kado Istimewa dar...              KOMPASTV
# 2  Live Event Rekam Jejak Prabowo Menjadi Preside...             METRO TV
# 3  Ulas Utas, Setahun Presiden Prabowo: 'Koruptor...            tvOneNews
# 4  Reshuffle Kabinet Merah Putih Prabowo-Gibran |...            tvOneNews
#
#    duration  upload_date                                          url  \
# 0       286     20251025  https://www.youtube.com/watch?v=IuE7NGQs_xk
# 1       456     20251024  https://www.youtube.com/watch?v=n7rRd0IF_yc
# 2       222     20241020  https://www.youtube.com/watch?v=6f17uwi2Vtw
# 3       567     20251023  https://www.youtube.com/watch?v=ExCBplKi6kw
# 4       467     20250917  https://www.youtube.com/watch?v=PqjwO9JEtBM
#
#                               audio_path  \
# 0  ./data/raw/youtube/audio/YT_00001.wav
# 1  ./data/raw/youtube/audio/YT_00002.wav
# 2  ./data/raw/youtube/audio/YT_00003.wav
# 3  ./data/raw/youtube/audio/YT_00004.wav
# 4  ./data/raw/youtube/audio/YT_00005.wav
#
#                                 thumbnail_path  \
# 0   ./data/raw/youtube/thumbnails/YT_00001.jpg
# 1   ./data/raw/youtube/thumbnails/YT_00002.jpg
# 2   ./data/raw/youtube/thumbnails/YT_00003.jpg
# 3  ./data/raw/youtube/thumbnails/YT_00004.webp
# 4   ./data/raw/youtube/thumbnails/YT_00005.jpg
#
#                   transcript_path  \
# 0  ./data/transcript/YT_00001.txt
# 1  ./data/transcript/YT_00002.txt
# 2  ./data/transcript/YT_00003.txt
# 3  ./data/transcript/YT_00004.txt
# 4  ./data/transcript/YT_00005.txt
#
#                                      transcript_text  transcript_length  \
# 0   lotus tonka Ayo! Ayo! Ayo! Ayo! Ayo! Ayo! Ayo...                204
# 1   yang saya hormati sebuah pondok bahagia ia ji...               3573
# 2   Puka perjalanan mudah bagi Prabowo Subianto h...               3071
# 3   Selama perioda satu tahun menjabat President ...               6428
# 4   Presiden Perabo Subiantok kembali melakukan p...               6049
#
#   language  label   status                   transcribed_at
# 0       id      0  success 2025-10-31 18:29:39.418341+00:00
# 1       id      0  success 2025-10-31 18:30:08.634255+00:00
# 2       id      0  success 2025-10-31 18:30:28.377608+00:00
# 3       id      0  success 2025-10-31 18:31:24.564553+00:00
# 4       id      0  success 2025-10-31 18:32:02.061119+00:00

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)                     # hapus angka
    text = re.sub(r'[' + string.punctuation + ']', '', text)  # hapus tanda baca
    text = re.sub(r'\s+', ' ', text)                    # hapus spasi berlebih
    text = re.sub(r'(?:\b(\w+)\b\s+)(?=\1\b)', '', text)  # hapus kata duplikat berurutan
    text = text.strip()
    return text

# %%
common_errors = {
    "peraputik": "merah putih",
    "perabo": "prabowo",
    "subiantok": "subianto",
    "president": "presiden",
    "puka": "buka",
    "menkopolokap": "menkopolhukam",
    "komps": "kompas",
    "presidenmu": "presiden",
    "parabohu": "prabowo",
    "perabohu": "prabowo",
    "perabuhu": "prabowo",
    "prasidian": "presiden",
    "menkopolokap": "menkopolhukam",
    "peraputi": "merah putih",
    "pariburnah": "paripurna",
    "pejapat": "pejabat"
}

def fix_common_errors(text):
    for k, v in common_errors.items():
        text = text.replace(k, v)
    return text

# %%
spell = SpellChecker(language=None)
spell.word_frequency.load_words([
    "prabowo","gibran","indonesia","merah","putih","kabinet",
    "tvone","kompastv","metrotv","sindonews","politik","presiden"
])  # tambahkan kata domain politik agar tidak dikoreksi salah

def correct_spelling(text):
    words = text.split()
    corrected = []
    for w in words:
        if len(w) > 3:
            corrected.append(spell.correction(w) or w)
        else:
            corrected.append(w)
    return ' '.join(corrected)

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
stop_words = set(stopwords.words('indonesian'))

def normalize_tokens(text):
    text = stemmer.stem(text)
    text = ' '.join([w for w in text.split() if w not in stop_words])
    return text

# %%
def normalize_pipeline(text):
    text = clean_text(text)
    text = fix_common_errors(text)
    text = correct_spelling(text)
    text = normalize_tokens(text)
    return text

df['normalized_transcript'] = df['transcript_text'].apply(normalize_pipeline)

# %%
df[['sample_id', 'channel', 'normalized_transcript']].to_csv("normalized_transcript.csv", index=False)
print("✅ Normalisasi selesai! File tersimpan sebagai 'normalized_transcript.csv'")

# Cek contoh hasil
df[['channel', 'normalized_transcript']].head(10)
